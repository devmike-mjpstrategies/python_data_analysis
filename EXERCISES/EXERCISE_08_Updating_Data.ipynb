# %% [markdown]
# ## Updating Data Exercise
#
# **This exercise uses the `netflix_titles.csv` dataset**

# %%
import pandas as pd

# %%
# read in the netflix_titles.csv dataset.  Make sure to tell pandas to use the correct separator character!
netflix = pd.read_csv("../DATA/netflix_titles.csv", sep="|")

# %%
# set the index to be the "show_id" (inplace)
netflix.set_index("show_id", inplace=True)

# %%
# Find the row with the id of s2202 and set its director to "Greg Whiteley"
netflix.loc["s2202", "director"] = "Greg Whiteley"

# %%
#Update the "duration" of the shows with index s2881 and s3601 to be "GONE TOO SOON"
netflix.loc[["s2881","s3601"], "duration"] = "GONE TOO SOON"
netflix.loc[['s2881','s3601']]
# Out:
#          Unnamed: 0     type                    title director  \
# show_id
# s2881          2880  TV Show  I Am Not Okay With This      NaN
# s3601          3600  TV Show                     GLOW      NaN
#
#                                                       cast        country  \
# show_id
# s2881    Sophia Lillis\t Wyatt Oleff\t Kathleen Rose Pe...  United States
# s3601    Alison Brie\t Betty Gilpin\t Marc Maron\t Brit...  United States
#
#                  date_added release_year rating       duration  \
# show_id
# s2881    February 26\t 2020   release_yr  TV-MA  GONE TOO SOON
# s3601       August 9\t 2019   release_yr  TV-MA  GONE TOO SOON
#
#                                              listed_in  \
# show_id
# s2881    TV Comedies\t TV Dramas\t TV Sci-Fi & Fantasy
# s3601                          TV Comedies\t TV Dramas
#
#         description\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t  \
# show_id
# s2881    Angsty Syd navigates high school awkwardness\t...
# s3601    In 1980s LA\t a crew of misfits reinvent thems...
#
#         show_id
# show_id
# s2881       NaN
# s3601       NaN

# %%
#rename the release_year column to "release_yr" in place
# netflix["release_year"] = "release_yr"
netflix.rename(columns={"release_year": "release_yr"}, inplace=True)
netflix
# Out:
#          Unnamed: 0     type                  title         director  \
# show_id
# s1                0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2                1  TV Show          Blood & Water              NaN
# s3                2  TV Show              Ganglands  Julien Leclercq
# s4                3  TV Show  Jailbirds New Orleans              NaN
# s5                4  TV Show           Kota Factory              NaN
# ...             ...      ...                    ...              ...
# s8803          8802    Movie                 Zodiac    David Fincher
# s8804          8803  TV Show            Zombie Dumb              NaN
# s8805          8804    Movie             Zombieland  Ruben Fleischer
# s8806          8805    Movie                   Zoom     Peter Hewitt
# s8807          8806    Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata\t Khosi Ngema\t Gail Mabalane\t Tha...   South Africa
# s3       Sami Bouajila\t Tracy Gotoas\t Samuel Jouy\t N...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More\t Jitendra Kumar\t Ranjan Raj\t Ala...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo\t Jake Gyllenhaal\t Robert Downey...  United States
# s8804                                                  NaN            NaN
# s8805    Jesse Eisenberg\t Woody Harrelson\t Emma Stone...  United States
# s8806    Tim Allen\t Courteney Cox\t Chevy Chase\t Kate...  United States
# s8807    Vicky Kaushal\t Sarah-Jane Dias\t Raaghav Chan...          India
#
#                   date_added  release_yr rating   duration  \
# show_id
# s1       September 25\t 2021  release_yr  PG-13     90 min
# s2       September 24\t 2021  release_yr  TV-MA  2 Seasons
# s3       September 24\t 2021  release_yr  TV-MA   1 Season
# s4       September 24\t 2021  release_yr  TV-MA   1 Season
# s5       September 24\t 2021  release_yr  TV-MA  2 Seasons
# ...                      ...         ...    ...        ...
# s8803     November 20\t 2019  release_yr      R    158 min
# s8804          July 1\t 2019  release_yr  TV-Y7  2 Seasons
# s8805      November 1\t 2019  release_yr      R     88 min
# s8806      January 11\t 2020  release_yr     PG     88 min
# s8807         March 2\t 2019  release_yr  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2       International TV Shows\t TV Dramas\t TV Mysteries
# s3       Crime TV Shows\t International TV Shows\t TV A...
# s4                                 Docuseries\t Reality TV
# s5       International TV Shows\t Romantic TV Shows\t T...
# ...                                                    ...
# s8803                     Cult Movies\t Dramas\t Thrillers
# s8804             Kids' TV\t Korean TV Shows\t TV Comedies
# s8805                             Comedies\t Horror Movies
# s8806                  Children & Family Movies\t Comedies
# s8807     Dramas\t International Movies\t Music & Musicals
#
#         description\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t  \
# show_id
# s1       As her father nears the end of his life\t film...
# s2       After crossing paths at a party\t a Cape Town ...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds\t flirtations and toilet talk go down am...
# s5       In a city of coaching centers known to train I...
# ...                                                    ...
# s8803    A political cartoonist\t a crime reporter and ...
# s8804    While living alone in a spooky town\t a young ...
# s8805    Looking to survive in a world taken over by zo...
# s8806    Dragged from civilian life\t a former superher...
# s8807    A scrappy but poor boy worms his way into a ty...
#
#         show_id    release_yr
# show_id
# s1          NaN  release_year
# s2          NaN  release_year
# s3          NaN  release_year
# s4          NaN  release_year
# s5          NaN  release_year
# ...         ...           ...
# s8803       NaN  release_year
# s8804       NaN  release_year
# s8805       NaN  release_year
# s8806       NaN  release_year
# s8807       NaN  release_year
#
# [8807 rows x 14 columns]

# %%
# Find the show called "Evil"
netflix.loc[netflix['title'] == "Evil"]

# Change its index label to s6666 inplace
netflix.rename({"s1907": "s6666"}, inplace=True)
netflix[netflix["title"] == "Evil"]
# Out:
#          Unnamed: 0     type title director  \
# show_id
# s6666          1906  TV Show  Evil      NaN
#
#                                                       cast        country  \
# show_id
# s6666    Katja Herbers\t Mike Colter\t Aasif Mandvi\t M...  United States
#
#                date_added  release_yr rating  duration  listed_in  \
# show_id
# s6666    October 1\t 2020  release_yr  TV-14  1 Season  TV Dramas
#
#         description\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t  \
# show_id
# s6666    A forensic psychologist partners with a Cathol...
#
#         show_id    release_yr
# show_id
# s6666     s6666  release_year

# %%
# In the rating column, please replace all instances of "UR" and "NR" with "No Rating".  Don't do it inplace!
netflix["rating"].replace(["UR", "NR"], "No Rating")
# Out:
# show_id
# s1       PG-13
# s2       TV-MA
# s3       TV-MA
# s4       TV-MA
# s5       TV-MA
#          ...
# s8803        R
# s8804    TV-Y7
# s8805        R
# s8806       PG
# s8807    TV-14
# Name: rating, Length: 8807, dtype: object

# %%
# Add a new column "is_fav" and set it to False for all rows
# Update the "is_fav" column to True for the titles in my list of favs (provided below)
favs = ["Young Royals", "Dark", "Big Mouth", "BoJack Horseman", "The Queen's Gambit", "American Vandal", "Russian Doll", "Godless"]
netflix["is_fav"] = "False"

# %%
netflix.loc[netflix["title"].isin(favs), 'is_fav'] = True

# %%
netflix['is_fav'].value_counts()
# Out:
# is_fav
# False    8799
# True        8
# Name: count, dtype: int64
